# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt 
import os

# %%
folder_path = '/Users/alina/Desktop/AFM/simulation_data' # /Users/alina/Desktop/AFM/simulation_data
file_str = 'gSentiment.csv'

gSentiment = pd.read_csv(os.path.join(folder_path, file_str))

# %%
gSentiment
# Out:
#     BehaviorSpace results (NetLogo 6.2.0)    Unnamed: 1   Unnamed: 2  \
# 0                         Goncalves.nlogo           NaN          NaN
# 1                              gSentiment           NaN          NaN
# 2           11/04/2024 08:37:13:742 -0500           NaN          NaN
# 3                               min-pxcor     max-pxcor    min-pycor
# 4                                     -50            50          -50
# ..                                    ...           ...          ...
# 765                                   NaN   0.149691207  0.149691207
# 766                                   NaN   0.212430154  0.212430154
# 767                                   NaN   0.071463582  0.071463582
# 768                                   NaN  -0.078521714  0.078521714
# 769                                   NaN  -0.124595628  0.124595628
#
#        Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6    Unnamed: 7  \
# ...

# %%
gSentiment.iloc[[7,10]+list(range(18,770))]
# Out:
#           BehaviorSpace results (NetLogo 6.2.0)    Unnamed: 1  \
# 7                          max-news-sensitivity           0.2
# 10   max-base-propensity-to-sentiment-contagion          0.25
# 18                                 all run data       returns
# 19                                          NaN             0
# 20                                          NaN  -0.093226154
# ..                                          ...           ...
# 765                                         NaN   0.149691207
# 766                                         NaN   0.212430154
# 767                                         NaN   0.071463582
# 768                                         NaN  -0.078521714
# 769                                         NaN  -0.124595628
#
#                Unnamed: 2    Unnamed: 3            Unnamed: 4   Unnamed: 5  \
# 7                     0.2           0.2                   0.2          0.2
# ...

# %%
gSentiment_data = gSentiment.iloc[[7,10]+list(range(18,770))]
gSentiment_data
# Out:
#           BehaviorSpace results (NetLogo 6.2.0)    Unnamed: 1  \
# 7                          max-news-sensitivity           0.2
# 10   max-base-propensity-to-sentiment-contagion          0.25
# 18                                 all run data       returns
# 19                                          NaN             0
# 20                                          NaN  -0.093226154
# ..                                          ...           ...
# 765                                         NaN   0.149691207
# 766                                         NaN   0.212430154
# 767                                         NaN   0.071463582
# 768                                         NaN  -0.078521714
# 769                                         NaN  -0.124595628
#
#                Unnamed: 2    Unnamed: 3            Unnamed: 4   Unnamed: 5  \
# 7                     0.2           0.2                   0.2          0.2
# ...

# %%
initial_cols = gSentiment.iloc[18, :].to_list()

# %%
gSentiment_data.columns = initial_cols

# %%
gSentiment_data
# Out:
#                                    all run data       returns  \
# 7                          max-news-sensitivity           0.2
# 10   max-base-propensity-to-sentiment-contagion          0.25
# 18                                 all run data       returns
# 19                                          NaN             0
# 20                                          NaN  -0.093226154
# ..                                          ...           ...
# 765                                         NaN   0.149691207
# 766                                         NaN   0.212430154
# 767                                         NaN   0.071463582
# 768                                         NaN  -0.078521714
# 769                                         NaN  -0.124595628
#
#      volatility-indicator       returns  volatility-indicator      returns  \
# 7                     0.2           0.2                   0.2          0.2
# ...

# %%
gReturns = gSentiment_data.loc[:,[f for f in initial_cols if f == 'returns']]
gReturns
# Out:
#           returns       returns      returns       returns       returns  \
# 7             0.2           0.2          0.2           0.4           0.4
# 10           0.25           0.5         0.75          0.25           0.5
# 18        returns       returns      returns       returns       returns
# 19              0             0            0             0             0
# 20   -0.093226154   0.126164102  0.100872463  -0.196941476  -0.238702088
# ..            ...           ...          ...           ...           ...
# 765   0.149691207  -0.146554259   0.23830997  -0.008332516   0.436917949
# 766   0.212430154  -0.019507891  0.300852858   0.196745417  -0.188118812
# 767   0.071463582   0.096951279  0.258308009   0.370061759  -0.383981963
# 768  -0.078521714  -0.018723655  0.108126654   0.548671699  -0.350455838
# 769  -0.124595628   0.085383786  0.039898049   0.703362415   -0.09440251
#
#           returns       returns       returns       returns       returns  \
# ...

# %%
gReturns = gReturns.reset_index(drop=True)
gReturns
# Out:
#           returns       returns      returns       returns       returns  \
# 0             0.2           0.2          0.2           0.4           0.4
# 1            0.25           0.5         0.75          0.25           0.5
# 2         returns       returns      returns       returns       returns
# 3               0             0            0             0             0
# 4    -0.093226154   0.126164102  0.100872463  -0.196941476  -0.238702088
# ..            ...           ...          ...           ...           ...
# 749   0.149691207  -0.146554259   0.23830997  -0.008332516   0.436917949
# 750   0.212430154  -0.019507891  0.300852858   0.196745417  -0.188118812
# 751   0.071463582   0.096951279  0.258308009   0.370061759  -0.383981963
# 752  -0.078521714  -0.018723655  0.108126654   0.548671699  -0.350455838
# 753  -0.124595628   0.085383786  0.039898049   0.703362415   -0.09440251
#
#           returns       returns       returns       returns       returns  \
# ...

# %%
gReturns.iloc[3:,0].astype(float)
# Out:
# 3      0.000000
# 4     -0.093226
# 5     -0.154593
# 6     -0.206352
# 7     -0.231840
#          ...
# 749    0.149691
# 750    0.212430
# 751    0.071464
# 752   -0.078522
# 753   -0.124596
# Name: returns, Length: 751, dtype: float64

# %%
time = range(1,752)
gret_02_025 = gReturns.iloc[3:,0].astype(float)
gret_02_05 = gReturns.iloc[3:,1].astype(float)
gret_02_075 = gReturns.iloc[3:,2].astype(float)

# %%
# Plot returns for varying max news sensitivity (mns) and max base propensity (bp) over time
plt.figure(figsize=(12, 6))

# returns at mns = 0.2 bs = 0.25
plt.plot(time, gret_02_025, label='BP=.25', color='black', linestyle='solid', linewidth=.2, marker='o', markerfacecolor='none', markeredgewidth=.2, markeredgecolor='black', markersize=3)

# returns at mns = .2 bs = .5
plt.plot(time, gret_02_05, label='BP=0.50', color='blue', linestyle='dashdot', linewidth=.2, marker='s', markerfacecolor='none', markeredgewidth=.2, markeredgecolor='blue', markersize=3)

# returns at mns = .2 bp = .75
plt.plot(time, gret_02_075, label='BP=0.75', color='red', linestyle='dashed', linewidth=.2, marker='<', markerfacecolor='none', markeredgewidth=.2, markeredgecolor='red', markersize=3)

# Adjust the border line (spine) width
for spine in plt.gca().spines.values():
    spine.set_linewidth(0.3)  # Set spine (border) line width

# Remove specific borders
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# labels and title
plt.xlabel('Time', fontsize=8, labelpad=1) # reduce padding
plt.ylabel('Returns', fontsize=8, labelpad=1)
plt.title('Goncalves Comparison of Returns, Max News Sensitivity, and Max Base Propensity Over Time')
plt.legend()

# Customize tick label font size
plt.tick_params(axis='both', which='major', labelsize=8) # reduce label size

# Save the plot at 300 DPI and COMMENT OUT when not saving
#plt.savefig('/Users/alina/Desktop/AFM/figure/gReturns_02.png', dpi=300, bbox_inches='tight')

# Display plot
plt.show()

# %%
def graphing_varying_greturns(time, list1, list2, list3, tosave=False, file_path: str=None, level: float=None):

    # Plot volatility at varying max news sensitivity (mns), and max base propensity (bp) over time
    plt.figure(figsize=(12, 6))

    # volatility 1 at mns =  bs = 
    plt.plot(time, list1, label='BP=.25', color='black', linestyle='solid', linewidth=.2,
              marker='o', markerfacecolor='none', markeredgewidth=.2, markeredgecolor='black', markersize=3)

    # volatility 2 at mns = condition1 bp = condition2
    plt.plot(time, list2, label='BP=0.50', color='blue', linestyle='dashdot', linewidth=.2,
             marker='s', markerfacecolor='none', markeredgewidth=.2, markeredgecolor='black', markersize=3)

    # Plot max base propensity
    plt.plot(time, list3, label='BP=0.75', color='red', linestyle='dashed', linewidth=.2,
             marker='<', markerfacecolor='none', markeredgewidth=.2, markeredgecolor='red', markersize=3)

    for spine in plt.gca().spines.values():
        spine.set_linewidth(.3)  # Set spine (border) line width

    # Remove specific borders
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)

    # Add labels and title
    plt.xlabel('Time')
    plt.ylabel('Returns')
    plt.title(f'Concalves Comparison of Returns, Max News Sensitivity={level}, and Max Base Propensity Over Time')
    plt.legend()

    # Customize tick label font size
    plt.tick_params(axis='both', which='major', labelsize=8) # reduce label size

    if tosave:
        # Save the plot at 300 DPI
        plt.savefig(file_path, dpi=300, bbox_inches='tight')
    else:
        pass

    # Display plot
    plt.show()

# %%
gReturns
# Out:
#           returns       returns      returns       returns       returns  \
# 0             0.2           0.2          0.2           0.4           0.4
# 1            0.25           0.5         0.75          0.25           0.5
# 2         returns       returns      returns       returns       returns
# 3               0             0            0             0             0
# 4    -0.093226154   0.126164102  0.100872463  -0.196941476  -0.238702088
# ..            ...           ...          ...           ...           ...
# 749   0.149691207  -0.146554259   0.23830997  -0.008332516   0.436917949
# 750   0.212430154  -0.019507891  0.300852858   0.196745417  -0.188118812
# 751   0.071463582   0.096951279  0.258308009   0.370061759  -0.383981963
# 752  -0.078521714  -0.018723655  0.108126654   0.548671699  -0.350455838
# 753  -0.124595628   0.085383786  0.039898049   0.703362415   -0.09440251
#
#           returns       returns       returns       returns       returns  \
# ...

# %%
#time = range(1,752) # uncomment if not previously defined
gret_04_025 = gReturns.iloc[3:,3].astype(float)
gret_04_05 = gReturns.iloc[3:,4].astype(float)
gret_04_075 = gReturns.iloc[3:,5].astype(float)

# %%
graphing_varying_greturns(time, list1=gret_02_025,list2=gret_04_05, list3=gret_04_075, level=.4) #, tosave=True, file_path='/Users/alina/Desktop/AFM/figure/gReturns_04.png')

# %%
gReturns
# Out:
#           returns       returns      returns       returns       returns  \
# 0             0.2           0.2          0.2           0.4           0.4
# 1            0.25           0.5         0.75          0.25           0.5
# 2         returns       returns      returns       returns       returns
# 3               0             0            0             0             0
# 4    -0.093226154   0.126164102  0.100872463  -0.196941476  -0.238702088
# ..            ...           ...          ...           ...           ...
# 749   0.149691207  -0.146554259   0.23830997  -0.008332516   0.436917949
# 750   0.212430154  -0.019507891  0.300852858   0.196745417  -0.188118812
# 751   0.071463582   0.096951279  0.258308009   0.370061759  -0.383981963
# 752  -0.078521714  -0.018723655  0.108126654   0.548671699  -0.350455838
# 753  -0.124595628   0.085383786  0.039898049   0.703362415   -0.09440251
#
#           returns       returns       returns       returns       returns  \
# ...

# %%
gReturns.iloc[3:,6].astype(float)
# Out:
# 3      0.000000
# 4      0.258896
# 5     -0.038330
# 6     -0.309283
# 7     -0.559063
#          ...
# 749   -0.413195
# 750    0.223213
# 751   -0.098716
# 752    0.233212
# 753   -0.104205
# Name: returns, Length: 751, dtype: float64

# %%
# Max News Sensitivity 0.6 and Base Propensity 0.25 0.5 0.75
gret_06_025 = gReturns.iloc[3:,6].astype(float)
gret_06_05 = gReturns.iloc[3:,7].astype(float)
gret_06_075 = gReturns.iloc[3:,8].astype(float)

# %%
graphing_varying_greturns(time, list1=gret_06_025, list2=gret_06_05, list3=gret_06_075, level=.6) #, tosave=True, file_path='/Users/alina/Desktop/AFM/figure/gReturns_06.png')
